# %% [markdown]
# ## Setup

# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import sqlpw

# %%
# Import PyMySQL (Not needed if mysqlclient is installed)
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ## E - Extract Data into DataFrames

# %% [markdown]
# ### Crypto Decoder

# %%
# Use Pandas to scrape the following site and find the abbreviations for the cryptos in the list
url = 'https://en.wikipedia.org/wiki/List_of_cryptocurrencies'
cryptos = ['Bitcoin', 'Ether or "Ethereum"']

# %%
# Use Panda's `read_html` to parse the url
tables = pd.read_html(url)
tables
# Out:
# [               0         1                    2                  3  \
#  0        Release    Status             Currency             Symbol
#  1           2009    Active              Bitcoin  BTC,[4][5] XBT, ₿
#  2           2011    Active             Litecoin             LTC, Ł
#  3           2011    Active             Namecoin                NMC
#  4           2011    Active            SwiftCoin                STC
#  5           2012    Active             Bytecoin                BCN
#  6           2012    Active             Peercoin                PPC
#  7           2013    Active             Dogecoin       DOGE, XDG, Ð
#  8       2013[23]    Active          Feathercoin             FTC, ₣
#  9   2013[26][27]    Active             Gridcoin                GRC
#  10          2013    Active            Primecoin                XPM
#  11          2013    Active   Ripple[34][35][36]            XRP[36]
#  12          2013    Active                  Nxt                NXT
#  13      2013[42]    Active              Skycoin                SKY
#  14          2014    Active           Auroracoin                AUR
#  15          2014  Inactive               Coinye          KOI, COYE
#  16          2014    Active                 Dash               DASH
#  17          2014    Active                  NEO                NEO
#  18          2014    Active             MazaCoin                MZC
#  19          2014    Active               Monero                XMR
#  20          2014    Active                  NEM                XEM
#  21          2014    Active              PotCoin                POT
#  22          2014    Active          Synereo AMP                AMP
#  23          2014    Active              Titcoin                TIT
#  24          2014    Active                Verge                XVG
#  25          2014    Active              Stellar                XLM
#  26          2014    Active             Vertcoin                VTC
#  27          2015    Active  Ether or "Ethereum"                ETH
#  28          2015    Active     Ethereum Classic                ETC
#  29          2015    Active               Tether               USDT
#  30          2015  Inactive              Neucoin                NEU
#  31          2016    Active               Decred                DCR
#  32          2016    Active                 Lisk                LSK
#  33          2016    Active                Zcash                ZEC
#  34          2017  Inactive           BitConnect                BCC
#  35          2017    Active         Bitcoin Cash            BCH[79]
#  36          2017    Active               EOS.IO                EOS
#  37          2018    Active              Cardano                ADA
#  38          2018  Inactive            KodakCoin                NaN
#  39          2018  Inactive                Petro                NaN
#  40          2018    Active      Bitcoin Private               BTCP
#
#                                                      4  \
#  0                                          Founder(s)
#  1                              Satoshi Nakamoto[nt 1]
#  2                                         Charlie Lee
#  3                              Vincent Durham[13][14]
#  4                                        Daniel Bruno
#  5                                                 NaN
#  6                           Sunny King(pseudonym)[17]
#  7                    Jackson Palmer& Billy Markus[20]
#  8   Peter Bushnell, Brasenose College of Oxford Un...
#  9                                    Rob Hälford [28]
#  10                          Sunny King(pseudonym)[17]
#  11                      Chris Larsen &Jed McCaleb[37]
#  12                                  BCNext(pseudonym)
#  13                       Brandon 'Synth' Smietana[43]
#  14                     Baldur Odinsson(pseudonym)[45]
#  15                                                NaN
#  16                      Evan Duffield &Kyle Hagan[47]
#  17                            Da Hongfei & Erik Zhang
#  18                               BTC Oyate Initiative
#  19                                   Monero Core Team
#  20                          UtopianFuture (pseudonym)
#  21                              Potcoin core dev team
#  22                   Dor Konforty & Greg Meredith[55]
#  23               Edward Mansfield & Richard Allen[58]
#  24                                            Sunerok
#  25                                        Jed McCaleb
#  26                                            Bushido
#  27                                Vitalik Buterin[66]
#  28                                                NaN
#  29                    Jan Ludovicus van der Velde[72]
#  30                                     Daniel Kaufman
#  31                                                NaN
#  32                        Max Kordek & Oliver Beddows
#  33                                       Zooko Wilcox
#  34                                                NaN
#  35                                                NaN
#  36                                        Dan Larimer
#  37                           Charles Hoskinson & IOHK
#  38                             Kodak and WENN Digital
#  39                               Venezuela Government
#  40                                                NaN
#
#                                                 5  \
#  0                                 Hash algorithm
#  1                                 SHA-256d[6][7]
#  2                                         Scrypt
#  3                                       SHA-256d
#  4                                        SHA-256
#  5                                     CryptoNote
#  6                                   SHA-256d[18]
#  7                                     Scrypt[21]
#  8                                      NeoScrypt
#  9                                         Scrypt
#  10                               1CC/2CC/TWN[32]
#  11                                     ECDSA[38]
#  12                                  SHA-256d[40]
#  13                                        SHA256
#  14                                        Scrypt
#  15                                        Scrypt
#  16                                           X11
#  17                           SHA-256 & RIPEMD160
#  18                                      SHA-256d
#  19                               CryptoNight[51]
#  20                                      SHA3-512
#  21                                        Scrypt
#  22                                           PoS
#  23                                      SHA-256d
#  24  Scrypt, x17, groestl, blake2s, and lyra2rev2
#  25         Stellar Consensus Protocol (SCP) [62]
#  26                                   Lyra2RE[64]
#  27                                    Ethash[67]
#  28                                    Ethash[67]
#  29                                 Omnicore [73]
#  30                                       SHA-256
#  31                                     Blake-256
#  32                                           PoS
#  33                                      Equihash
#  34                                           NaN
#  35                                      SHA-256d
#  36                                           NaN
#  37                                           NaN
#  38                                    Ethash[82]
#  39                                  onixCoin[83]
#  40                                      Equihash
#
#                                           6  \
#  0   Programming language of implementation
#  1                                   C++[8]
#  2                                  C++[12]
#  3                                  C++[15]
#  4                                      NaN
#  5                                  C++[16]
#  6                                  C++[19]
#  7                                  C++[22]
#  8                                  C++[24]
#  9                                  C++[29]
#  10                     TypeScript, C++[33]
#  11                                 C++[39]
#  12                                Java[41]
#  13                                  CX/CXO
#  14                                 C++[46]
#  15                                     NaN
#  16                                 C++[48]
#  17                                  C#[49]
#  18                                 C++[50]
#  19                                 C++[52]
#  20                                Java[53]
#  21                                 C++[54]
#  22                         Scala, Java[56]
#  23                     TypeScript, C++[59]
#  24                              C, C++[61]
#  25                              C, C++[63]
#  26                                 C++[65]
#  27                             C++, Go[68]
#  28                                     NaN
#  29                                     NaN
#  30                                     NaN
#  31                                  Go[75]
#  32                          JavaScript[76]
#  33                                 C++[78]
#  34                                     NaN
#  35                                     NaN
#  36           WebAssembly, Rust, C, C++[80]
#  37                             Haskell[81]
#  38                                     NaN
#  39                                 C++[84]
#  40                                 C++[86]
#
#                                                   7  \
#  0   Cryptocurrency blockchain (PoS, PoW, or other)
#  1                                        PoW[7][9]
#  2                                              PoW
#  3                                              PoW
#  4                                              PoW
#  5                                              PoW
#  6                                        PoW & PoS
#  7                                              PoW
#  8                                              NaN
#  9                                Decentralized PoS
#  10                                         PoW[32]
#  11                                     "Consensus"
#  12                                             PoS
#  13                                     Obelisk[44]
#  14                                             PoW
#  15                                             PoW
#  16                    PoW & Proof of Service[nt 2]
#  17                                            dBFT
#  18                                             PoW
#  19                                             PoW
#  20                                             POI
#  21                                             PoS
#  22                                             PoS
#  23                                             PoW
#  24                                             PoW
#  25           Stellar Consensus Protocol (SCP) [62]
#  26                                             PoW
#  27                                             PoW
#  28                                             PoW
#  29                                             PoW
#  30                                       PoW & PoS
#  31                                  PoW/PoS Hybrid
#  32                                             PoS
#  33                                             PoW
#  34                                             NaN
#  35                                             PoW
#  36                                   delegated PoS
#  37                                   Ouroboros PoS
#  38                                             NaN
#  39                                             NaN
#  40                                             PoW
#
#                                                      8
#  0                                               Notes
#  1   The first and most widely used decentralized l...
#  2   The first cryptocurrency to use Scrypt as a ha...
#  3     Also acts as an alternative, decentralized DNS.
#  4   First block chain to support currency creation...
#  5   First cryptocurrency based on the CryptoNote a...
#  6   The first cryptocurrency to use POW and POS fu...
#  7                    Based on the Doge internet meme.
#  8   Approx. 60 seconds block time.[25] Originally ...
#  9   Linked to citizen science through the Berkeley...
#  10  Uses the finding of prime chains composed of C...
#  11  Designed for peer to peer debt transfer. Not b...
#  12  Specifically designed as a flexible platform t...
#  13                              Peer-to-peer Internet
#  14  Created as an alternative currency for Iceland...
#  15  Used American hip hop artist Kanye West as its...
#  16  A bitcoin-based currency featuring instant tra...
#  17  China based cryptocurrency, formerly ANT Share...
#  18  The underlying software is derived from that o...
#  19  Privacy-centric coin using the CryptoNote prot...
#  20  The first hybrid public/private blockchain sol...
#  21  Developed to service the legalized cannabis in...
#  22  Trying to create a world computer, Synereo’s 2...
#  23  The first cryptocurrency to be nominated for a...
#  24  Features anonymous transactions using Tor and ...
#  25  Open-source, decentralized global financial ne...
#  26  Next-gen ASIC resistance and first cryptocurre...
#  27          Supports Turing-complete smart contracts.
#  28  An alternative version of Ethereum[69] whose b...
#  29  Tether claims to be backed by USD at a 1 to 1 ...
#  30  Based on Peercoin, attempted to improve securi...
#  31            Built in governance and hybrid PoW/PoS.
#  32  Open blockchain platform for decentralized, an...
#  33  The first open, permissionless financial syste...
#  34  BitConnect was described as an open source, al...
#  35  Hard fork from Bitcoin, Increased Block size f...
#  36  Feeless Smart contract platform for decentrali...
#  37  The Ada cryptocurrency runs on the Cardano pla...
#  38  KodakCoin is a "photographer-centric" blockcha...
#  39  Stated by Nicolás Maduro to be backed by Venez...
#  40  Coin uses zkSNARK for anonymous payments. Hard...  ,
#                             0   \
#  0         vteCryptocurrencies
#  1                  Technology
#  2        Consensus mechanisms
#  3    Proof-of-work currencies
#  4               SHA-256-based
#  5                Ethash-based
#  6                Scrypt-based
#  7              Equihash-based
#  8            CryptoNote-based
#  9                   X11-based
#  10  Proof-of-stake currencies
#  11              ERC-20 tokens
#  12           Other currencies
#  13             Related topics
#  14    Category  Commons  List
#  15              SHA-256-based
#  16               Ethash-based
#  17               Scrypt-based
#  18             Equihash-based
#  19           CryptoNote-based
#  20                  X11-based
#
#                                                     1              2   \
#  0                                                 NaN            NaN
#  1   Atomic swap Blockchain Cryptocurrency tumbler ...            NaN
#  2   Proof-of-authority Proof-of-space Proof-of-sta...            NaN
#  3   SHA-256-based Bitcoin Bitcoin Cash Counterpart...  SHA-256-based
#  4   Bitcoin Bitcoin Cash Counterparty Namecoin Nxt...            NaN
#  5                           Ethereum Ethereum Classic            NaN
#  6          Bitcoin Gold Dogecoin Feathercoin Litecoin            NaN
#  7                                         Zcash Zcoin            NaN
#  8                                     Bytecoin Monero            NaN
#  9                                          Dash Petro            NaN
#  10                      Ada EOS.IO Lisk Tezos VeChain            NaN
#  11  æternity Aion Augur Basic Attention Token Bina...            NaN
#  12  BitShares Filecoin NEM NEO Primecoin Ripple St...            NaN
#  13  Airdrop Anonymous Internet banking BitLicense ...            NaN
#  14                                                NaN            NaN
#  15  Bitcoin Bitcoin Cash Counterparty Namecoin Nxt...            NaN
#  16                          Ethereum Ethereum Classic            NaN
#  17         Bitcoin Gold Dogecoin Feathercoin Litecoin            NaN
#  18                                        Zcash Zcoin            NaN
#  19                                    Bytecoin Monero            NaN
#  20                                         Dash Petro            NaN
#
#                                                     3             4   \
#  0                                                 NaN           NaN
#  1                                                 NaN           NaN
#  2                                                 NaN           NaN
#  3   Bitcoin Bitcoin Cash Counterparty Namecoin Nxt...  Ethash-based
#  4                                                 NaN           NaN
#  5                                                 NaN           NaN
#  6                                                 NaN           NaN
#  7                                                 NaN           NaN
#  8                                                 NaN           NaN
#  9                                                 NaN           NaN
#  10                                                NaN           NaN
#  11                                                NaN           NaN
#  12                                                NaN           NaN
#  13                                                NaN           NaN
#  14                                                NaN           NaN
#  15                                                NaN           NaN
#  16                                                NaN           NaN
#  17                                                NaN           NaN
#  18                                                NaN           NaN
#  19                                                NaN           NaN
#  20                                                NaN           NaN
#
#                             5             6   \
#  0                         NaN           NaN
#  1                         NaN           NaN
#  2                         NaN           NaN
#  3   Ethereum Ethereum Classic  Scrypt-based
#  4                         NaN           NaN
#  5                         NaN           NaN
#  6                         NaN           NaN
#  7                         NaN           NaN
#  8                         NaN           NaN
#  9                         NaN           NaN
#  10                        NaN           NaN
#  11                        NaN           NaN
#  12                        NaN           NaN
#  13                        NaN           NaN
#  14                        NaN           NaN
#  15                        NaN           NaN
#  16                        NaN           NaN
#  17                        NaN           NaN
#  18                        NaN           NaN
#  19                        NaN           NaN
#  20                        NaN           NaN
#
#                                              7               8            9   \
#  0                                          NaN             NaN          NaN
#  1                                          NaN             NaN          NaN
#  2                                          NaN             NaN          NaN
#  3   Bitcoin Gold Dogecoin Feathercoin Litecoin  Equihash-based  Zcash Zcoin
#  4                                          NaN             NaN          NaN
#  5                                          NaN             NaN          NaN
#  6                                          NaN             NaN          NaN
#  7                                          NaN             NaN          NaN
#  8                                          NaN             NaN          NaN
#  9                                          NaN             NaN          NaN
#  10                                         NaN             NaN          NaN
#  11                                         NaN             NaN          NaN
#  12                                         NaN             NaN          NaN
#  13                                         NaN             NaN          NaN
#  14                                         NaN             NaN          NaN
#  15                                         NaN             NaN          NaN
#  16                                         NaN             NaN          NaN
#  17                                         NaN             NaN          NaN
#  18                                         NaN             NaN          NaN
#  19                                         NaN             NaN          NaN
#  20                                         NaN             NaN          NaN
#
#                    10               11         12          13
#  0                NaN              NaN        NaN         NaN
#  1                NaN              NaN        NaN         NaN
#  2                NaN              NaN        NaN         NaN
#  3   CryptoNote-based  Bytecoin Monero  X11-based  Dash Petro
#  4                NaN              NaN        NaN         NaN
#  5                NaN              NaN        NaN         NaN
#  6                NaN              NaN        NaN         NaN
#  7                NaN              NaN        NaN         NaN
#  8                NaN              NaN        NaN         NaN
#  9                NaN              NaN        NaN         NaN
#  10               NaN              NaN        NaN         NaN
#  11               NaN              NaN        NaN         NaN
#  12               NaN              NaN        NaN         NaN
#  13               NaN              NaN        NaN         NaN
#  14               NaN              NaN        NaN         NaN
#  15               NaN              NaN        NaN         NaN
#  16               NaN              NaN        NaN         NaN
#  17               NaN              NaN        NaN         NaN
#  18               NaN              NaN        NaN         NaN
#  19               NaN              NaN        NaN         NaN
#  20               NaN              NaN        NaN         NaN  ,
#                    0                                                  1
#  0     SHA-256-based  Bitcoin Bitcoin Cash Counterparty Namecoin Nxt...
#  1      Ethash-based                          Ethereum Ethereum Classic
#  2      Scrypt-based         Bitcoin Gold Dogecoin Feathercoin Litecoin
#  3    Equihash-based                                        Zcash Zcoin
#  4  CryptoNote-based                                    Bytecoin Monero
#  5         X11-based                                         Dash Petro]

# %%
# Find the cryptocurrency DataFrame in the list of DataFrames as assign it to `df`
# Assign the columns appropriate names
df = tables[0]
df.columns = ['release', 'status', 'currency', 'symbol', 'founders', 'hash algorithm', 'prog. language', 'blockchain', 'notes']
df.head()
# Out:
#    release  status   currency             symbol                founders  \
# 0  Release  Status   Currency             Symbol              Founder(s)
# 1     2009  Active    Bitcoin  BTC,[4][5] XBT, ₿  Satoshi Nakamoto[nt 1]
# 2     2011  Active   Litecoin             LTC, Ł             Charlie Lee
# 3     2011  Active   Namecoin                NMC  Vincent Durham[13][14]
# 4     2011  Active  SwiftCoin                STC            Daniel Bruno
#
#    hash algorithm                          prog. language  \
# 0  Hash algorithm  Programming language of implementation
# 1  SHA-256d[6][7]                                  C++[8]
# 2          Scrypt                                 C++[12]
# 3        SHA-256d                                 C++[15]
# 4         SHA-256                                     NaN
#
#                                        blockchain  \
# 0  Cryptocurrency blockchain (PoS, PoW, or other)
# 1                                       PoW[7][9]
# 2                                             PoW
# 3                                             PoW
# 4                                             PoW
#
#                                                notes
# 0                                              Notes
# 1  The first and most widely used decentralized l...
# 2  The first cryptocurrency to use Scrypt as a ha...
# 3    Also acts as an alternative, decentralized DNS.
# 4  First block chain to support currency creation...

# %%
# Drop all columns except for the currency and symbol
del df['release'], df['status'], df['founders'], df['hash algorithm'], df['prog. language'], df['blockchain'],df['notes']
df
# Out:
#                currency             symbol
# 0              Currency             Symbol
# 1               Bitcoin  BTC,[4][5] XBT, ₿
# 2              Litecoin             LTC, Ł
# 3              Namecoin                NMC
# 4             SwiftCoin                STC
# 5              Bytecoin                BCN
# 6              Peercoin                PPC
# 7              Dogecoin       DOGE, XDG, Ð
# 8           Feathercoin             FTC, ₣
# 9              Gridcoin                GRC
# 10            Primecoin                XPM
# 11   Ripple[34][35][36]            XRP[36]
# 12                  Nxt                NXT
# 13              Skycoin                SKY
# 14           Auroracoin                AUR
# 15               Coinye          KOI, COYE
# 16                 Dash               DASH
# 17                  NEO                NEO
# 18             MazaCoin                MZC
# 19               Monero                XMR
# 20                  NEM                XEM
# 21              PotCoin                POT
# 22          Synereo AMP                AMP
# 23              Titcoin                TIT
# 24                Verge                XVG
# 25              Stellar                XLM
# 26             Vertcoin                VTC
# 27  Ether or "Ethereum"                ETH
# 28     Ethereum Classic                ETC
# 29               Tether               USDT
# 30              Neucoin                NEU
# 31               Decred                DCR
# 32                 Lisk                LSK
# 33                Zcash                ZEC
# 34           BitConnect                BCC
# 35         Bitcoin Cash            BCH[79]
# 36               EOS.IO                EOS
# 37              Cardano                ADA
# 38            KodakCoin                NaN
# 39                Petro                NaN
# 40      Bitcoin Private               BTCP

# %%
# Drop the first row and set the index to the `currency` column
df = df.iloc[1:]
df.set_index('currency', inplace=True)
df.head()
# Out:
#           release  status             symbol                founders  \
# currency
# Bitcoin      2009  Active  BTC,[4][5] XBT, ₿  Satoshi Nakamoto[nt 1]
# Litecoin     2011  Active             LTC, Ł             Charlie Lee
# Namecoin     2011  Active                NMC  Vincent Durham[13][14]
# SwiftCoin    2011  Active                STC            Daniel Bruno
# Bytecoin     2012  Active                BCN                     NaN
#
#            hash algorithm prog. language blockchain  \
# currency
# Bitcoin    SHA-256d[6][7]         C++[8]  PoW[7][9]
# Litecoin           Scrypt        C++[12]        PoW
# Namecoin         SHA-256d        C++[15]        PoW
# SwiftCoin         SHA-256            NaN        PoW
# Bytecoin       CryptoNote        C++[16]        PoW
#
#                                                        notes
# currency
# Bitcoin    The first and most widely used decentralized l...
# Litecoin   The first cryptocurrency to use Scrypt as a ha...
# Namecoin     Also acts as an alternative, decentralized DNS.
# SwiftCoin  First block chain to support currency creation...
# Bytecoin   First cryptocurrency based on the CryptoNote a...

# %%
# Loop through the list of cryptocurrencies and store the symbols in a list.
# Use the DataFrame to perform the lookup.

symbols=[]
for currency in cryptos:
    symbols.append(df.loc[currency].symbol)
symbols
# Out:
# ['BTC,[4][5] XBT, \u20bf', 'ETH']

# %%
# Clean up the symbol for Bitcoin
symbols[0]=symbols[0][0:3]
symbols
# Out:
# ['BTC', 'ETH']

# %%
# Clean up the currency name for Ethereum
cryptos[1]=cryptos[1][10:18]
cryptos
# Out:
# ['Bitcoin', 'Ethereum']

# %%
# Store the lists into a DataFrame
crypto_d={'Cryptocurrency':cryptos,'Symbol':symbols}
crypto_df=pd.DataFrame(crypto_d)
crypto_df
# Out:
#   Cryptocurrency Symbol
# 0        Bitcoin    BTC
# 1       Ethereum    ETH

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
# Extract the Bitcoin CSV and preview
csv_file = "../Resources/bitcoin_price.csv"
bitcoin_data_df = pd.read_csv(csv_file)
bitcoin_data_df.head()
# Out:
#            Date     Open     High       Low    Close         Volume  \
# 0  Feb 20, 2018  11231.8  11958.5  11231.80  11403.7  9,926,540,000
# 1  Feb 19, 2018  10552.6  11273.8  10513.20  11225.3  7,652,090,000
# 2  Feb 18, 2018  11123.4  11349.8  10326.00  10551.8  8,744,010,000
# 3  Feb 17, 2018  10207.5  11139.5  10149.40  11112.7  8,660,880,000
# 4  Feb 16, 2018  10135.7  10324.1   9824.82  10233.9  7,296,160,000
#
#         Market Cap
# 0  189,536,000,000
# 1  178,055,000,000
# 2  187,663,000,000
# 3  172,191,000,000
# 4  170,960,000,000

# %%
# Extract the Ethereum CSV and preview
csv_file = "../Resources/ethereum_price.csv"
ethereum_data_df = pd.read_csv(csv_file)
ethereum_data_df.head()
# Out:
#            Date    Open    High     Low   Close         Volume      Market Cap
# 0  Feb 20, 2018  943.57  965.26  892.95  895.37  2,545,260,000  92,206,500,000
# 1  Feb 19, 2018  921.67  957.78  921.55  943.87  2,169,020,000  90,047,700,000
# 2  Feb 18, 2018  973.35  982.93  915.45  923.92  2,567,290,000  95,077,100,000
# 3  Feb 17, 2018  944.75  976.60  940.75  974.12  2,525,720,000  92,264,000,000
# 4  Feb 16, 2018  934.79  950.00  917.85  944.21  2,369,450,000  91,272,100,000

# %% [markdown]
# ## T - Transform DataFrames

# %% [markdown]
# ### Transform Bitcoin DataFrame

# %%
# Copy the Bitcoin DataFrame into a new DataFrame
new_bitcoin_data_df = bitcoin_data_df[['Date', 'Close']].copy()

# Only include the rows corresponding to dates after August 7, 2015 (beginning of Ethereum data set)
new_bitcoin_data_df = new_bitcoin_data_df.loc[0:928]

# Reset the index, rename index column to "id", and set column "id" as the index column for MySQL connection
new_bitcoin_data_df = new_bitcoin_data_df.reset_index()
new_bitcoin_data_df = new_bitcoin_data_df.rename(columns={"index": "id", "Close": f"{symbols[0]}_Close"})
new_bitcoin_data_df = new_bitcoin_data_df.set_index("id", inplace=False)
new_bitcoin_data_df
# Out:
#              Date  BTC Close
# id
# 0    Feb 20, 2018   11403.70
# 1    Feb 19, 2018   11225.30
# 2    Feb 18, 2018   10551.80
# 3    Feb 17, 2018   11112.70
# 4    Feb 16, 2018   10233.90
# 5    Feb 15, 2018   10166.40
# 6    Feb 14, 2018    9494.63
# 7    Feb 13, 2018    8598.31
# 8    Feb 12, 2018    8926.57
# 9    Feb 11, 2018    8129.97
# 10   Feb 10, 2018    8621.90
# 11   Feb 09, 2018    8736.98
# 12   Feb 08, 2018    8265.59
# 13   Feb 07, 2018    7621.30
# 14   Feb 06, 2018    7754.00
# 15   Feb 05, 2018    6955.27
# 16   Feb 04, 2018    8277.01
# 17   Feb 03, 2018    9174.91
# 18   Feb 02, 2018    8830.75
# 19   Feb 01, 2018    9170.54
# 20   Jan 31, 2018   10221.10
# 21   Jan 30, 2018   10106.30
# 22   Jan 29, 2018   11296.40
# 23   Jan 28, 2018   11786.30
# 24   Jan 27, 2018   11440.70
# 25   Jan 26, 2018   11171.40
# 26   Jan 25, 2018   11259.40
# 27   Jan 24, 2018   11359.40
# 28   Jan 23, 2018   10868.40
# 29   Jan 22, 2018   10931.40
# ..            ...        ...
# 899  Sep 05, 2015     235.02
# 900  Sep 04, 2015     230.30
# 901  Sep 03, 2015     227.18
# 902  Sep 02, 2015     229.28
# 903  Sep 01, 2015     228.12
# 904  Aug 31, 2015     230.06
# 905  Aug 30, 2015     228.76
# 906  Aug 29, 2015     229.78
# 907  Aug 28, 2015     231.40
# 908  Aug 27, 2015     224.77
# 909  Aug 26, 2015     225.83
# 910  Aug 25, 2015     221.61
# 911  Aug 24, 2015     210.50
# 912  Aug 23, 2015     228.17
# 913  Aug 22, 2015     230.39
# 914  Aug 21, 2015     232.57
# 915  Aug 20, 2015     235.35
# 916  Aug 19, 2015     226.68
# 917  Aug 18, 2015     211.08
# 918  Aug 17, 2015     257.98
# 919  Aug 16, 2015     258.51
# 920  Aug 15, 2015     261.55
# 921  Aug 14, 2015     265.68
# 922  Aug 13, 2015     264.08
# 923  Aug 12, 2015     266.38
# 924  Aug 11, 2015     270.39
# 925  Aug 10, 2015     264.47
# 926  Aug 09, 2015     265.08
# 927  Aug 08, 2015     261.00
# 928  Aug 07, 2015     279.58
#
# [929 rows x 2 columns]

# %% [markdown]
# ### Transform Ethereum DataFrame

# %%
# Copy the Bitcoin DataFrame into a new DataFrame
new_ethereum_data_df = ethereum_data_df[['Date', 'Close']].copy()

# Reset the index, rename index column to "id", and set column "id" as the index column for MySQL connection
new_ethereum_data_df = new_ethereum_data_df.reset_index()
new_ethereum_data_df = new_ethereum_data_df.rename(columns={"index": "id", "Close": f"{symbols[1]}_Close"})
new_ethereum_data_df = new_ethereum_data_df.set_index("id", inplace=False)
new_ethereum_data_df
# Out:
#              Date    ETH Close
# id
# 0    Feb 20, 2018   895.370000
# 1    Feb 19, 2018   943.870000
# 2    Feb 18, 2018   923.920000
# 3    Feb 17, 2018   974.120000
# 4    Feb 16, 2018   944.210000
# 5    Feb 15, 2018   936.980000
# 6    Feb 14, 2018   923.560000
# 7    Feb 13, 2018   845.260000
# 8    Feb 12, 2018   868.710000
# 9    Feb 11, 2018   814.660000
# 10   Feb 10, 2018   860.410000
# 11   Feb 09, 2018   883.870000
# 12   Feb 08, 2018   817.810000
# 13   Feb 07, 2018   757.070000
# 14   Feb 06, 2018   793.120000
# 15   Feb 05, 2018   697.950000
# 16   Feb 04, 2018   834.680000
# 17   Feb 03, 2018   964.020000
# 18   Feb 02, 2018   915.780000
# 19   Feb 01, 2018  1036.790000
# 20   Jan 31, 2018  1118.310000
# 21   Jan 30, 2018  1071.130000
# 22   Jan 29, 2018  1182.360000
# 23   Jan 28, 2018  1246.010000
# 24   Jan 27, 2018  1107.070000
# 25   Jan 26, 2018  1055.170000
# 26   Jan 25, 2018  1056.030000
# 27   Jan 24, 2018  1058.780000
# 28   Jan 23, 2018   986.230000
# 29   Jan 22, 2018  1003.260000
# ..            ...          ...
# 899  Sep 05, 2015     1.340000
# 900  Sep 04, 2015     1.270000
# 901  Sep 03, 2015     1.260000
# 902  Sep 02, 2015     1.290000
# 903  Sep 01, 2015     1.350000
# 904  Aug 31, 2015     1.360000
# 905  Aug 30, 2015     1.320000
# 906  Aug 29, 2015     1.180000
# 907  Aug 28, 2015     1.190000
# 908  Aug 27, 2015     1.150000
# 909  Aug 26, 2015     1.160000
# 910  Aug 25, 2015     1.140000
# 911  Aug 24, 2015     1.230000
# 912  Aug 23, 2015     1.350000
# 913  Aug 22, 2015     1.380000
# 914  Aug 21, 2015     1.400000
# 915  Aug 20, 2015     1.460000
# 916  Aug 19, 2015     1.260000
# 917  Aug 18, 2015     1.090000
# 918  Aug 17, 2015     1.200000
# 919  Aug 16, 2015     1.570000
# 920  Aug 15, 2015     1.690000
# 921  Aug 14, 2015     1.830000
# 922  Aug 13, 2015     1.830000
# 923  Aug 12, 2015     1.220000
# 924  Aug 11, 2015     1.070000
# 925  Aug 10, 2015     0.708448
# 926  Aug 09, 2015     0.701897
# 927  Aug 08, 2015     0.753325
# 928  Aug 07, 2015     2.770000
#
# [929 rows x 2 columns]

# %% [markdown]
# ### Create database connection

# %%
# Connect to database
connection_string = f"root:{sqlpw}@localhost/crypto_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['bitcoin', 'ethereum']

# %% [markdown]
# ## L - Load DataFrames into database

# %%
new_bitcoin_data_df.to_sql(name='bitcoin', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in read(self)
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'BTC Close' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-48-660c38d04733> in <module>()
# ----> 1 new_bitcoin_data_df.to_sql(name='bitcoin', con=engine, if_exists='append', index=True)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1147                          schema=schema, dtype=dtype)
#    1148         table.create()
# -> 1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#    1151             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     661
#     662                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 663                 self._execute_insert(conn, keys, chunk_iter)
#     664
#     665     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     636         """Insert data into this table with database connection"""
#     637         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 638         conn.execute(*self.insert_statement(data, conn))
#     639
#     640     def insert(self, chunksize=None):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     514                 sql = sql.encode(self.encoding, 'surrogateescape')
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#     518
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     725         else:
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#     729         if result.server_status is not None:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in read(self)
#    1064     def read(self):
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#    1068             if first_packet.is_ok_packet():
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'BTC Close' in 'field list'") [SQL: 'INSERT INTO bitcoin (id, `Date`, `BTC Close`) VALUES (%(id_m0)s, %(Date_m0)s, %(BTC Close_m0)s), (%(id_m1)s, %(Date_m1)s, %(BTC Close_m1)s), (%(id_m2)s, %(Date_m2)s, %(BTC Close_m2)s), (%(id_m3)s, %(Date_m3)s, %(BTC Close_m3)s), (%(id_m4)s, %(Date_m4)s, %(BTC Close_m4)s), (%(id_m5)s, %(Date_m5)s, %(BTC Close_m5)s), (%(id_m6)s, %(Date_m6)s, %(BTC Close_m6)s), (%(id_m7)s, %(Date_m7)s, %(BTC Close_m7)s), (%(id_m8)s, %(Date_m8)s, %(BTC Close_m8)s), (%(id_m9)s, %(Date_m9)s, %(BTC Close_m9)s), (%(id_m10)s, %(Date_m10)s, %(BTC Close_m10)s), (%(id_m11)s, %(Date_m11)s, %(BTC Close_m11)s), (%(id_m12)s, %(Date_m12)s, %(BTC Close_m12)s), (%(id_m13)s, %(Date_m13)s, %(BTC Close_m13)s), (%(id_m14)s, %(Date_m14)s, %(BTC Close_m14)s), (%(id_m15)s, %(Date_m15)s, %(BTC Close_m15)s), (%(id_m16)s, %(Date_m16)s, %(BTC Close_m16)s), (%(id_m17)s, %(Date_m17)s, %(BTC Close_m17)s), (%(id_m18)s, %(Date_m18)s, %(BTC Close_m18)s), (%(id_m19)s, %(Date_m19)s, %(BTC Close_m19)s), (%(id_m20)s, %(Date_m20)s, %(BTC Close_m20)s), (%(id_m21)s, %(Date_m21)s, %(BTC Close_m21)s), (%(id_m22)s, %(Date_m22)s, %(BTC Close_m22)s), (%(id_m23)s, %(Date_m23)s, %(BTC Close_m23)s), (%(id_m24)s, %(Date_m24)s, %(BTC Close_m24)s), (%(id_m25)s, %(Date_m25)s, %(BTC Close_m25)s), (%(id_m26)s, %(Date_m26)s, %(BTC Close_m26)s), (%(id_m27)s, %(Date_m27)s, %(BTC Close_m27)s), (%(id_m28)s, %(Date_m28)s, %(BTC Close_m28)s), (%(id_m29)s, %(Date_m29)s, %(BTC Close_m29)s), (%(id_m30)s, %(Date_m30)s, %(BTC Close_m30)s), (%(id_m31)s, %(Date_m31)s, %(BTC Close_m31)s), (%(id_m32)s, %(Date_m32)s, %(BTC Close_m32)s), (%(id_m33)s, %(Date_m33)s, %(BTC Close_m33)s), (%(id_m34)s, %(Date_m34)s, %(BTC Close_m34)s), (%(id_m35)s, %(Date_m35)s, %(BTC Close_m35)s), (%(id_m36)s, %(Date_m36)s, %(BTC Close_m36)s), (%(id_m37)s, %(Date_m37)s, %(BTC Close_m37)s), (%(id_m38)s, %(Date_m38)s, %(BTC Close_m38)s), (%(id_m39)s, %(Date_m39)s, %(BTC Close_m39)s), (%(id_m40)s, %(Date_m40)s, %(BTC Close_m40)s), (%(id_m41)s, %(Date_m41)s, %(BTC Close_m41)s), (%(id_m42)s, %(Date_m42)s, %(BTC Close_m42)s), (%(id_m43)s, %(Date_m43)s, %(BTC Close_m43)s), (%(id_m44)s, %(Date_m44)s, %(BTC Close_m44)s), (%(id_m45)s, %(Date_m45)s, %(BTC Close_m45)s), (%(id_m46)s, %(Date_m46)s, %(BTC Close_m46)s), (%(id_m47)s, %(Date_m47)s, %(BTC Close_m47)s), (%(id_m48)s, %(Date_m48)s, %(BTC Close_m48)s), (%(id_m49)s, %(Date_m49)s, %(BTC Close_m49)s), (%(id_m50)s, %(Date_m50)s, %(BTC Close_m50)s), (%(id_m51)s, %(Date_m51)s, %(BTC Close_m51)s), (%(id_m52)s, %(Date_m52)s, %(BTC Close_m52)s), (%(id_m53)s, %(Date_m53)s, %(BTC Close_m53)s), (%(id_m54)s, %(Date_m54)s, %(BTC Close_m54)s), (%(id_m55)s, %(Date_m55)s, %(BTC Close_m55)s), (%(id_m56)s, %(Date_m56)s, %(BTC Close_m56)s), (%(id_m57)s, %(Date_m57)s, %(BTC Close_m57)s), (%(id_m58)s, %(Date_m58)s, %(BTC Close_m58)s), (%(id_m59)s, %(Date_m59)s, %(BTC Close_m59)s), (%(id_m60)s, %(Date_m60)s, %(BTC Close_m60)s), (%(id_m61)s, %(Date_m61)s, %(BTC Close_m61)s), (%(id_m62)s, %(Date_m62)s, %(BTC Close_m62)s), (%(id_m63)s, %(Date_m63)s, %(BTC Close_m63)s), (%(id_m64)s, %(Date_m64)s, %(BTC Close_m64)s), (%(id_m65)s, %(Date_m65)s, %(BTC Close_m65)s), (%(id_m66)s, %(Date_m66)s, %(BTC Close_m66)s), (%(id_m67)s, %(Date_m67)s, %(BTC Close_m67)s), (%(id_m68)s, %(Date_m68)s, %(BTC Close_m68)s), (%(id_m69)s, %(Date_m69)s, %(BTC Close_m69)s), (%(id_m70)s, %(Date_m70)s, %(BTC Close_m70)s), (%(id_m71)s, %(Date_m71)s, %(BTC Close_m71)s), (%(id_m72)s, %(Date_m72)s, %(BTC Close_m72)s), (%(id_m73)s, %(Date_m73)s, %(BTC Close_m73)s), (%(id_m74)s, %(Date_m74)s, %(BTC Close_m74)s), (%(id_m75)s, %(Date_m75)s, %(BTC Close_m75)s), (%(id_m76)s, %(Date_m76)s, %(BTC Close_m76)s), (%(id_m77)s, %(Date_m77)s, %(BTC Close_m77)s), (%(id_m78)s, %(Date_m78)s, %(BTC Close_m78)s), (%(id_m79)s, %(Date_m79)s, %(BTC Close_m79)s), (%(id_m80)s, %(Date_m80)s, %(BTC Close_m80)s), (%(id_m81)s, %(Date_m81)s, %(BTC Close_m81)s), (%(id_m82)s, %(Date_ ...

# %%
new_ethereum_data_df.to_sql(name='ethereum', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in read(self)
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'ETH Close' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-41-fdd40c7ad215> in <module>()
# ----> 1 new_ethereum_data_df.to_sql(name='ethereum', con=engine, if_exists='append', index=True)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1147                          schema=schema, dtype=dtype)
#    1148         table.create()
# -> 1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#    1151             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     661
#     662                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 663                 self._execute_insert(conn, keys, chunk_iter)
#     664
#     665     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     636         """Insert data into this table with database connection"""
#     637         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 638         conn.execute(*self.insert_statement(data, conn))
#     639
#     640     def insert(self, chunksize=None):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     514                 sql = sql.encode(self.encoding, 'surrogateescape')
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#     518
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     725         else:
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#     729         if result.server_status is not None:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in read(self)
#    1064     def read(self):
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#    1068             if first_packet.is_ok_packet():
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'ETH Close' in 'field list'") [SQL: 'INSERT INTO ethereum (id, `Date`, `ETH Close`) VALUES (%(id_m0)s, %(Date_m0)s, %(ETH Close_m0)s), (%(id_m1)s, %(Date_m1)s, %(ETH Close_m1)s), (%(id_m2)s, %(Date_m2)s, %(ETH Close_m2)s), (%(id_m3)s, %(Date_m3)s, %(ETH Close_m3)s), (%(id_m4)s, %(Date_m4)s, %(ETH Close_m4)s), (%(id_m5)s, %(Date_m5)s, %(ETH Close_m5)s), (%(id_m6)s, %(Date_m6)s, %(ETH Close_m6)s), (%(id_m7)s, %(Date_m7)s, %(ETH Close_m7)s), (%(id_m8)s, %(Date_m8)s, %(ETH Close_m8)s), (%(id_m9)s, %(Date_m9)s, %(ETH Close_m9)s), (%(id_m10)s, %(Date_m10)s, %(ETH Close_m10)s), (%(id_m11)s, %(Date_m11)s, %(ETH Close_m11)s), (%(id_m12)s, %(Date_m12)s, %(ETH Close_m12)s), (%(id_m13)s, %(Date_m13)s, %(ETH Close_m13)s), (%(id_m14)s, %(Date_m14)s, %(ETH Close_m14)s), (%(id_m15)s, %(Date_m15)s, %(ETH Close_m15)s), (%(id_m16)s, %(Date_m16)s, %(ETH Close_m16)s), (%(id_m17)s, %(Date_m17)s, %(ETH Close_m17)s), (%(id_m18)s, %(Date_m18)s, %(ETH Close_m18)s), (%(id_m19)s, %(Date_m19)s, %(ETH Close_m19)s), (%(id_m20)s, %(Date_m20)s, %(ETH Close_m20)s), (%(id_m21)s, %(Date_m21)s, %(ETH Close_m21)s), (%(id_m22)s, %(Date_m22)s, %(ETH Close_m22)s), (%(id_m23)s, %(Date_m23)s, %(ETH Close_m23)s), (%(id_m24)s, %(Date_m24)s, %(ETH Close_m24)s), (%(id_m25)s, %(Date_m25)s, %(ETH Close_m25)s), (%(id_m26)s, %(Date_m26)s, %(ETH Close_m26)s), (%(id_m27)s, %(Date_m27)s, %(ETH Close_m27)s), (%(id_m28)s, %(Date_m28)s, %(ETH Close_m28)s), (%(id_m29)s, %(Date_m29)s, %(ETH Close_m29)s), (%(id_m30)s, %(Date_m30)s, %(ETH Close_m30)s), (%(id_m31)s, %(Date_m31)s, %(ETH Close_m31)s), (%(id_m32)s, %(Date_m32)s, %(ETH Close_m32)s), (%(id_m33)s, %(Date_m33)s, %(ETH Close_m33)s), (%(id_m34)s, %(Date_m34)s, %(ETH Close_m34)s), (%(id_m35)s, %(Date_m35)s, %(ETH Close_m35)s), (%(id_m36)s, %(Date_m36)s, %(ETH Close_m36)s), (%(id_m37)s, %(Date_m37)s, %(ETH Close_m37)s), (%(id_m38)s, %(Date_m38)s, %(ETH Close_m38)s), (%(id_m39)s, %(Date_m39)s, %(ETH Close_m39)s), (%(id_m40)s, %(Date_m40)s, %(ETH Close_m40)s), (%(id_m41)s, %(Date_m41)s, %(ETH Close_m41)s), (%(id_m42)s, %(Date_m42)s, %(ETH Close_m42)s), (%(id_m43)s, %(Date_m43)s, %(ETH Close_m43)s), (%(id_m44)s, %(Date_m44)s, %(ETH Close_m44)s), (%(id_m45)s, %(Date_m45)s, %(ETH Close_m45)s), (%(id_m46)s, %(Date_m46)s, %(ETH Close_m46)s), (%(id_m47)s, %(Date_m47)s, %(ETH Close_m47)s), (%(id_m48)s, %(Date_m48)s, %(ETH Close_m48)s), (%(id_m49)s, %(Date_m49)s, %(ETH Close_m49)s), (%(id_m50)s, %(Date_m50)s, %(ETH Close_m50)s), (%(id_m51)s, %(Date_m51)s, %(ETH Close_m51)s), (%(id_m52)s, %(Date_m52)s, %(ETH Close_m52)s), (%(id_m53)s, %(Date_m53)s, %(ETH Close_m53)s), (%(id_m54)s, %(Date_m54)s, %(ETH Close_m54)s), (%(id_m55)s, %(Date_m55)s, %(ETH Close_m55)s), (%(id_m56)s, %(Date_m56)s, %(ETH Close_m56)s), (%(id_m57)s, %(Date_m57)s, %(ETH Close_m57)s), (%(id_m58)s, %(Date_m58)s, %(ETH Close_m58)s), (%(id_m59)s, %(Date_m59)s, %(ETH Close_m59)s), (%(id_m60)s, %(Date_m60)s, %(ETH Close_m60)s), (%(id_m61)s, %(Date_m61)s, %(ETH Close_m61)s), (%(id_m62)s, %(Date_m62)s, %(ETH Close_m62)s), (%(id_m63)s, %(Date_m63)s, %(ETH Close_m63)s), (%(id_m64)s, %(Date_m64)s, %(ETH Close_m64)s), (%(id_m65)s, %(Date_m65)s, %(ETH Close_m65)s), (%(id_m66)s, %(Date_m66)s, %(ETH Close_m66)s), (%(id_m67)s, %(Date_m67)s, %(ETH Close_m67)s), (%(id_m68)s, %(Date_m68)s, %(ETH Close_m68)s), (%(id_m69)s, %(Date_m69)s, %(ETH Close_m69)s), (%(id_m70)s, %(Date_m70)s, %(ETH Close_m70)s), (%(id_m71)s, %(Date_m71)s, %(ETH Close_m71)s), (%(id_m72)s, %(Date_m72)s, %(ETH Close_m72)s), (%(id_m73)s, %(Date_m73)s, %(ETH Close_m73)s), (%(id_m74)s, %(Date_m74)s, %(ETH Close_m74)s), (%(id_m75)s, %(Date_m75)s, %(ETH Close_m75)s), (%(id_m76)s, %(Date_m76)s, %(ETH Close_m76)s), (%(id_m77)s, %(Date_m77)s, %(ETH Close_m77)s), (%(id_m78)s, %(Date_m78)s, %(ETH Close_m78)s), (%(id_m79)s, %(Date_m79)s, %(ETH Close_m79)s), (%(id_m80)s, %(Date_m80)s, %(ETH Close_m80)s), (%(id_m81)s, %(Date_m81)s, %(ETH Close_m81)s), (%(id_m82)s, %(Date ...
